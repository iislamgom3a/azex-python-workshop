# %% [markdown]
# # User Profile Formatter

# %% [markdown]
# Create a program that:
#
# 1. Asks the user for:
#    - name
#    - age
#    - height in cm
# 2. Convert age and height to numbers.
# 3. Calculate:
#    - age after 5 years
#    - height in meters
# 4. Print a formatted summary.
#
# ### Example
# Input:
# ```
# Enter name: Ali
# Enter age: 20
# Enter height (cm): 175
# ```
# output:
# ```
# Hello Ali
# You are 20 years old
# In 5 years you will be 25
# Your height in meters is 1.75
# ```

# %%
# solution

# %% [markdown]
# # String Analyzer
#
# ### Requirements
# Input a sentence and print:
#
# - length of string
# - lowercase version
# - uppercase version
# - word count
# - first and last character
# - reversed string
# - number of vowels
#
# ### Example
# input:
# ```
# hello world
# ```
# output:
# ```
# Length: 11
# Lower: hello world
# Upper: HELLO WORLD
# Words: 2
# First: h
# Last: d
# Reverse: dlrow olleh
# Vowels: 3
# ```

# %%
# solution

# %% [markdown]
# # Simple Calculator
#
#
# ### Requirements
# 1. Ask user for:
#    - number 1
#    - operator (+ - * / %)
#    - number 2
# 2. Use `if/elif/else` to perform operation.
# 3. Handle division by zero.
#
# ### Example
# input:
# ```
# enter first number: 10
# enter operator(+ - * / %): /
# enter second number: 5
# ```
# output:
# ```
# 10 / 5 = 2
# ```
