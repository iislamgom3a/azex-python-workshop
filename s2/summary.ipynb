# %% [markdown]
# # Functions

# %%
# defention
def azex_function():
    print("Hello islam")
    print("Hello islam")
    print("Hello islam")
    print("Hello islam")
    print("Hello islam")
    print("Hello islam")
    print("Hello islam")

# %%
# calling
azex_function()
# Out:
# Hello islam
# Hello islam
# Hello islam
# Hello islam
# Hello islam
# Hello islam
# Hello islam

# %%
def function_name():
    pass

# %%
def hello(first_name):
    print(f"hello {first_name}")

# %%
hello("Islam")
hello(12)
# Out:
# hello Islam
# hello 12

# %%
def calc(x, y):
    return x + y

# %%
sum = calc(10, 10)
print(sum)
# Out:
# 20

# %%
print(calc(1, 2))
# Out:
# 3

# %%
def hello():
# Out:
#   Cell In[21], line 1
#     def hello():
#                 ^
# _IncompleteInputError: incomplete input

# %%
def hello():
    pass

# %%
def hello(first_name):
    print(f"hello {first_name}")

hello("khaled")
hello("islam")
# Out:
# hello khaled
# hello islam

# %%
def hello(first_name, last_name):
    print(f"Hello mr {first_name} {last_name}")


hello("Islam", "moahmed")
# Out:
# Hello mr Islam moahmed

# %%
hello("Islam")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 hello("Islam")
#
# TypeError: hello() missing 1 required positional argument: 'last_name'

# %%
def hello(first_name = 'friend'):
    print(f"Hello {first_name}")

hello("islam")
# Out:
# Hello islam

# %%
hello()
# Out:
# Hello friend

# %%
def my_function(animal, name):
  print("I have a", animal)
  print("My", animal + "'s name is", name)

my_function(animal = "dog", name = "Buddy")
my_function("dog","Buddy") # postional args
my_function(name = "Buddy", animal='buddy') # keywork args
# Out:
# I have a dog
# My dog's name is Buddy
# I have a dog
# My dog's name is Buddy
# I have a buddy
# My buddy's name is Buddy

# %%
def my_function(animal, name, age):
  print("I have a", age, "year old", animal, "named", name)

# positional arguments must come before keyword arguments
my_function("dog", name = "Buddy", age = 5)
# Out:
# I have a 5 year old dog named Buddy

# %%
def my_function(*args):
    print(f"first arg: {args[0]}")
    print(f"second arg: {args[1]}")

my_function("islam", "ahmed")
# Out:
# first arg: islam
# second arg: ahmed

# %%
# combine regular parameters with *arg

def my_function(greeting, *names):
  for name in names:
    print(greeting, name)

my_function("Hello", "Islam", "Ahmed", "marwa")
# Out:
# Hello Islam
# Hello Ahmed
# Hello marwa

# %%
def my_function(**name):
    """
    - a fucntion that takes first_name , last_name and return a string
    """
    print("His name is " + name["first_name"] + " "+name["last_name"])

my_function(first_name = "Islam", last_name = "Gomaa")
# Out:
# His name is Islam Gomaa

# %%
help(my_function)
# Out:
# Help on function my_function in module __main__:
#
# my_function(**name)
#     - a fucntion that takes first_name , last_name and return a string

# %%
my_function(first_name = "islam", last_name='mohamed')
# Out:
# His name is islam mohamed

# %%
x = 10 # global

def azex():
    x = 'ahmed' # local
    print(x)

azex()
print(x)
# Out:
# ahmed
# 10

# %%
x = 10 # global

def azex():
    print(x)

azex()
print(x)
# Out:
# 10
# 10

# %%
x = 10 # global

def azex():
    global x
    x = 'ahmed' # local
    print(x)

azex()
print(x)
# Out:
# ahmed
# ahmed

# %% [markdown]
# # other data types

# %% [markdown]
# ## list

# %%
li = [1, 2, 3, 4]
print(li)
# Out:
# [1, 2, 3, 4]

# %%
li = [10]
print(li)
# Out:
# [10]

# %%
li =  [1,3.23, 'khaled', True]

# %%
print(li)
# Out:
# [1, 3.23, 'khaled', True]

# %%
len(li)
# Out:
# 4

# %%
type(li)
# Out:
# list

# %%
student = list()

# %%
print(student)
# Out:
# []

# %%
type(student)
# Out:
# list

# %%
li = [1, 2, 3, 4]
print(1 in li)
# Out:
# True

# %%
print(li[0])
# Out:
# 1

# %%
print(li[1])
# Out:
# 2

# %%
print(li[-1])
# Out:
# 4

# %%
print(li[0:])
# Out:
# [1, 2, 3, 4]

# %%
print(li)
# Out:
# [1, 2, 3, 4]

# %%
li.append(5)

# %%
print(li)
# Out:
# [1, 2, 3, 4, 5]

# %%
li.insert(0, 'ahmed')

# %%
print(li)
# Out:
# ['ahmed', 1, 2, 3, 4, 5]

# %%
li2 = [6, 7]
li.extend(li2)

# %%
print(li)
# Out:
# ['ahmed', 1, 2, 3, 4, 5, 6, 7]

# %%
li.remove(7)

# %%
print(li)
# Out:
# ['ahmed', 1, 2, 3, 4, 5, 6]

# %%
li.pop(-1)
# Out:
# 6

# %%
print(li)
# Out:
# ['ahmed', 1, 2, 3, 4, 5]

# %%
li.pop()
# Out:
# 5

# %%
li.pop()
# Out:
# 4

# %%
print(li)
# Out:
# ['ahmed', 1, 2, 3]

# %%
li3 = li.copy()
print(li3)
# Out:
# ['ahmed', 1, 2, 3]

# %%
li.clear()

# %%
print(li)
# Out:
# []

# %%
del li
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 del li
#
# NameError: name 'li' is not defined

# %%
print(li)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 print(li)
#
# NameError: name 'li' is not defined

# %%
# looping 
thislist = ["apple", "banana", "cherry"]
for hamada in thislist:
  print(hamada)
# Out:
# apple
# banana
# cherry

# %%
# Out:
# ['banana', 'kiwi', 'mango', 'orange', 'pineapple']

# %%
thislist.sort(reverse=True)
print(thislist)
# Out:
# ['pineapple', 'orange', 'mango', 'kiwi', 'banana']

# %%
li = [1, 3, 1, 2]
print(li.count(1))
# Out:
# 2

# %%
li = [4, 5, 1, 2]
li.sort()
print(li)
# Out:
# [1, 2, 4, 5]

# %%
li.sort(reverse=True)
print(li)
# Out:
# [5, 4, 2, 1]

# %%
li = [4, 5, 1, 2]
print(li)
# Out:
# [4, 5, 1, 2]

# %%
li.reverse()

# %%
print(li)
# Out:
# [2, 1, 5, 4]

# %% [markdown]
# # Tuple

# %%
tub = (1, 2, 3, 4)

# %%
type(tub)
# Out:
# tuple

# %%
len(tub)
# Out:
# 4

# %%
var2 = (1, "islam", True)

# %%
var2[0] = 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 var2[0] = 2
#
# TypeError: 'tuple' object does not support item assignment

# %%
var =  [1, "islam", True]

# %%
type(var)
# Out:
# list

# %%
var[0] = 10

# %%
print(var)
# Out:
# [10, 'islam', True]

# %%
print(var2)
# Out:
# (1, 'islam', True)

# %%
var2[0] = 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 var2[0] = 10
#
# TypeError: 'tuple' object does not support item assignment

# %%
# note #
# Changing a tuple: convert into list then change then convert back into tuple.
var = (1, 2, 3)
var = list(var)
var[0] = 'ahmed'
var = tuple(var)
print(var)
print(type(var))


# or create a new one then add them
thistuple = ("apple", "banana", "cherry")
y = ("orange",)
thistuple += y
# Out:
# ('ahmed', 2, 3)
# <class 'tuple'>

# %%
# note #
# Changing a tuple: convert into list then change then convert back into tuple.
var = (1, 2, 3)
var = list(var)
var[0] = 'ahmed'
var = tuple(var)
print(var)
print(type(var))


# or create a new one then add them
thistuple = ("apple", "banana", "cherry")
y = ("orange",)
thistuple += y
# Out:
# ('ahmed', 2, 3)
# <class 'tuple'>

# %%
student = ("ahmed", "islam", "khaled", "marwa")

(st1, st2, *st3) = student
print(st1)
# Out:
# ahmed

# %%
print(st1)
# Out:
# ahmed

# %%
print(st2)
# Out:
# islam

# %%
print(st3)
# Out:
# ['khaled', 'marwa']

# %%
type(st3)
# Out:
# list

# %%
thistuple = ("apple", "banana", "cherry")
for y in thistuple:
  print(y)
# Out:
# apple
# banana
# cherry

# %%
var3 = (1, 2, 3, 4, 5, 3, 2, 2)
print(var3.count(2))
print(var3.index(5))
# Out:
# 3
# 4

# %%
set_var = {"a", 1, "ahmed", True}

# %%
print(set_var)
# Out:
# {'ahmed', 1, 'a'}

# %%
len(set_var)
# Out:
# 3

# %%
type(set_var)
# Out:
# set

# %%
set_var2 = set()

# %%
type(set_var2)
# Out:
# set

# %%
if "a" in set_var:
    print("OK")
# Out:
# OK

# %%
print(set_var[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[140], line 1
# ----> 1 print(set_var[0])
#
# TypeError: 'set' object is not subscriptable

# %%
# no dubplicates, unordered
var = {"islam", "islam", "ahmed", "ahmed"}
print(var)
# Out:
# {'ahmed', 'islam'}

# %%
thisset = {"ahmed", "ali", "khaled"}
for x in thisset: 
    print(x)
# Out:
# ahmed
# khaled
# ali

# %%
set_var = {"b", "a", "b", "a"}
print(set_var)
# Out:
# {'b', 'a'}

# %%
set_var.add("c")

# %%
print(set_var)
# Out:
# {'b', 'a', 'c'}

# %%
li = [1, 3]
set_var.update(li)
print(set_var)
# Out:
# {'b', 1, 3, 'a', 'c'}

# %%
set_var.remove("b")

# %%
print(set_var)
# Out:
# {1, 3, 'a', 'c'}

# %%
set_var.remove("khaled")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[150], line 1
# ----> 1 set_var.remove("khaled")
#
# KeyError: 'khaled'

# %%
set_var.discard("khaled")

# %%
print(set_var)
# Out:
# {1, 3, 'a', 'c'}

# %%
item = set_var.pop()

# %%
print(item)
# Out:
# 1

# %%
print(set_var)
# Out:
# {3, 'a', 'c'}

# %%
set_var.clear()

# %%
print(set_var)
# Out:
# set()

# %%
del set_var 
print(set_var)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[158], line 2
#       1 del set_var
# ----> 2 print(set_var)
#
# NameError: name 'set_var' is not defined

# %%
# Union -> same as update but return a new set, update modifies
s = {'ahmed', "ali"}
set_var = {'a', 'b'}
new_set = set_var.union(s)
print(new_set)

# intersection
s1, s2 = {1, 2, 3, 4}, {3, 4, 5, 5}
print(s1.intersection(s2))
# Out:
# {'b', 'ahmed', 'a', 'ali'}
# {3, 4}

# %%
print(s2)
# Out:
# {3, 4, 5}

# %%
dic_var = {
    "id": 1,
    "age": 22,
    "name": "islam"
}

# %%
print(dic_var)
# Out:
# {'id': 1, 'age': 22, 'name': 'islam'}

# %%
session = dict()
type(session)
# Out:
# dict

# %%
len(dic_var)
# Out:
# 3

# %%
print(dic_var['age'])
# Out:
# 22

# %%
print(dic_var["name"])
# Out:
# islam

# %%
print(dic_var.get("id"))
# Out:
# 1

# %%
# Duplicates keys aren't allowed
student = {
    "id": 323232, 
    "id": 4343343, # overwrite the the last 'id' value
    'age': 14
}
print(student)
# Out:
# {'id': 4343343, 'age': 14}

# %%
print(dic_var.keys())
# Out:
# dict_keys(['id', 'age', 'name'])

# %%
print(dic_var.values())
# Out:
# dict_values([1, 22, 'islam'])

# %%
print(dic_var.keys())
# Out:
# dict_keys(['id', 'age', 'name'])

# %%
# itmes 

student_items = student.items()
print(student_items) # list of tuples
# Out:
# dict_items([('id', 4343343), ('age', 14)])

# %%
# in keyword
if 'id' in student: 
    print("we have the id")
# Out:
# we have the id

# %%
print(student)
# Out:
# {'id': 4343343, 'age': 14}

# %%
student['id'] = 43

# %%
print(student)
# Out:
# {'id': 43, 'age': 14}

# %%
# using update

thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict.update({"year": 2020})

# %%
thisdict["color"] = "red"

# %%
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2020, 'color': 'red'}

# %%
thisdict.update({"status": "used"})

# %%
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2020, 'color': 'red', 'status': 'used'}

# %%
thisdict.pop("status")
# Out:
# 'used'

# %%
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2020, 'color': 'red'}

# %%
item = thisdict.popitem()

# %%
print(item)
# Out:
# ('color', 'red')

# %%
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2020}

# %%
del thisdict

# %%
print(thisdict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[207], line 1
# ----> 1 print(thisdict)
#
# NameError: name 'thisdict' is not defined

# %%
# lopping
dic_var = {
    "id": 213,
    "name": ("ahmed", "ali"),
    "scores": [54, 542, 234]
}

for x, y in dic_var.items():
    print(x, y)
# Out:
# id 213
# name ('ahmed', 'ali')
# scores [54, 542, 234]

# %%
items = dic_var.items()
print(items)
# Out:
# dict_items([('id', 213), ('name', 'ahmed')])

# %%
items = list(items)

# %%
type(items)
# Out:
# list

# %%
items[0]
# Out:
# ('id', 213)

# %%
item = items[0]

# %%
item
# Out:
# ('id', 213)

# %%
(x, y) = item

# %%
print(x, y)
# Out:
# id 213

# %%
dic_var2 = dic_var.copy()
dic_var.clear()
del dic_var

# %%
myfamily = {
  "child1" : {
    "name" : "doaa",
    "year" : 2004
  },
  "child2" : {
    "name" : "ahmed",
    "year" : 2007
  },
  "child3" : {
    "name" : "ali",
    "year" : 2011
  }
}

# %%
print(myfamily["child1"]['name'])
# Out:
# doaa
