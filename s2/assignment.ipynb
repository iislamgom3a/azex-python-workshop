# %% [markdown]
# # Assignment

# %% [markdown]
# ## Function with Arguments and Return
#
# Write a function `calculate_fx(x)` that returns the value of:
#
# f(x) = 2x³ + 3x + 10
#
# Then:
# - Call the function with different values.
# - Print the returned result.
# - Do not repeat the formula outside the function.
#
# ### Example Input
# x = 2
# x = -1
#
# ### Example Output
# - 32
# - 5

# %%
# write yor solution here

# %% [markdown]
# ---
# ## Flexible Calculator using *args
#
# Create a function `calculator(operation, *numbers)` that:
#
# - Accepts a symbol as the first argument: "+", "-", or "*"
# - Performs the operation on all given numbers
# - Returns the result
# - If the symbol is invalid, return: "Invalid operation"
#
# ### Example Input
# calculator("+", 1, 2, 3, 4)
# calculator("*", 2, 3, 4)
# calculator("x", 5, 6)
#
# ### Example Output
# ```
# 10
# 24
# Invalid operation
# ```

# %%
# write yor solution here

# %% [markdown]
# # You are given the following dictionary:
#
# ```
# students = {
#     "student1": {"name": "Ali", "score": 85},
#     "student2": {"name": "Sara", "score": 92},
#     "student3": {"name": "Omar", "score": 78}
# }
# ```
#
# Tasks:
# 1. Write a function `get_top_student(data)` that returns the name of the student with the highest score.
# 2. Print all student names using a loop.
# 3. Add a new student to the dictionary.
#
# ### Example Output
#
# ```
# Top student: Sara
# all students:
# Ali
# Sara
# Omar
# ```
